# %%
import os
from copy import deepcopy

import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split,KFold,GridSearchCV,cross_val_score

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import SplineTransformer,PolynomialFeatures,StandardScaler,MinMaxScaler



from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# MODELS
from sklearn.neighbors import NearestNeighbors

# %%
df=pd.read_csv('C:/Users/rsher/Documents/Projects/FindYourHome/model-public/2023-06-16_temp_data.csv')
# Out:
# C:\Users\rsher\AppData\Local\Temp\ipykernel_30884\1013519566.py:1: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('C:/Users/rsher/Documents/Projects/FindYourHome/model-public/2023-06-16_temp_data.csv')

# %%
random_state=np.random.randint(0,999)
np.random.seed(random_state)
    

bedrooms_probabilities=df['BEDS'].value_counts(normalize=True)
bedrooms=np.random.choice(bedrooms_probabilities.index,p=bedrooms_probabilities.values)

bathrooms_probabilities=df['BATHS'].value_counts(normalize=True)
bathrooms=np.random.choice(bathrooms_probabilities.index,p=bathrooms_probabilities.values)
sqft_probabilities=df['SQUARE FEET'].value_counts(normalize=True)
sqft=np.random.choice(sqft_probabilities.index,p=sqft_probabilities.values)

# %%
bedrooms,bathrooms,sqft
# Out:
# (4.0, 3.0, 1364.0)

# %%
import random
def shuffle_data(df:pd.DataFrame):
    random_state=random.randint(0,999)
    
    df=df.sample(frac=1, replace=False, random_state=random_state,ignore_index=False)
    
    return 
    
ret=shuffle_data(df)

ret
# Out:
#         Unnamed: 0    SALE TYPE            TimeStamp SOLD DATE  \
# 101688      101688  MLS Listing  2023-06-16 13:20:28       NaN
# 454000      454000  MLS Listing  2023-06-16 13:20:28       NaN
# 126371      126371  MLS Listing  2023-06-16 13:20:28       NaN
# 177692      177692  MLS Listing  2023-06-16 13:20:28       NaN
# 320517      320517  MLS Listing  2023-06-16 13:20:28       NaN
# ...            ...          ...                  ...       ...
# 226432      226432  MLS Listing  2023-06-16 13:20:28       NaN
# 297557      297557  MLS Listing  2023-06-16 13:20:28       NaN
# 22607        22607  MLS Listing  2023-06-16 13:20:28       NaN
# 294983      294983  MLS Listing  2023-06-16 13:20:28       NaN
# 11136        11136  MLS Listing  2023-06-16 13:20:28       NaN
#
#                     PROPERTY TYPE               ADDRESS            CITY  \
# 101688    Multi-Family (2-4 Unit)      17 Hawthorne Ter      Torrington
# 454000  Single Family Residential   18913 E Buckeye Ave  Spokane Valley
# 126371                  Townhouse        713 Carroll St           Akron
# 177692  Single Family Residential        3964 South Cir           Largo
# 320517  Single Family Residential     131 Gaybourne Way      Versailles
# ...                           ...                   ...             ...
# 226432  Single Family Residential     14895 S 274th Ave          Coweta
# 297557  Single Family Residential  1113 E Red River Cir      Clearwater
# 22607   Single Family Residential       1887 S 215th Dr         Buckeye
# 294983  Single Family Residential  145 Shiloh Vista Ave          Urbana
# 11136   Single Family Residential         1343 Maple St          Sidney
#
#        STATE OR PROVINCE ZIP OR POSTAL CODE     PRICE  ...  STATUS  \
# 101688                CT               6790  299000.0  ...  Active
# 454000                WA              99027  430000.0  ...  Active
# 126371                OH              44304  180000.0  ...  Active
# 177692                FL              33774  875000.0  ...  Active
# 320517                KY              40383  299900.0  ...  Active
# ...                  ...                ...       ...  ...     ...
# 226432                OK              74429  285000.0  ...  Active
# 297557                KS              67026  350000.0  ...  Active
# 22607                 AZ              85326  409900.0  ...  Active
# 294983                IA              52345  425000.0  ...  Active
# 11136                 NE              69162  130000.0  ...  Active
#
#         NEXT OPEN HOUSE START TIME NEXT OPEN HOUSE END TIME  \
# 101688                         NaN                      NaN
# 454000                         NaN                      NaN
# 126371                         NaN                      NaN
# 177692                         NaN                      NaN
# 320517                         NaN                      NaN
# ...                            ...                      ...
# 226432       June-17-2023 02:00 PM    June-17-2023 04:00 PM
# 297557                         NaN                      NaN
# 22607                          NaN                      NaN
# 294983                         NaN                      NaN
# 11136                          NaN                      NaN
#
#         URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 101688  https://www.redfin.com/CT/Torrington/17-Hawtho...
# 454000  https://www.redfin.com/WA/Spokane-Valley/18913...
# 126371  https://www.redfin.com/OH/Akron/713-Carroll-St...
# 177692  https://www.redfin.com/FL/Largo/3964-South-Cir...
# 320517  https://www.redfin.com/KY/Versailles/131-Gaybo...
# ...                                                   ...
# 226432  https://www.redfin.com/OK/Coweta/14895-S-274th...
# 297557  https://www.redfin.com/KS/Clearwater/1113-Red-...
# 22607   https://www.redfin.com/AZ/Buckeye/1887-S-215th...
# 294983  https://www.redfin.com/IA/Urbana/145-Shiloh-Vi...
# 11136   https://www.redfin.com/NE/Sidney/1343-Maple-St...
#
#                SOURCE       MLS#  FAVORITE  INTERESTED   LATITUDE   LONGITUDE
# 101688      Smart MLS  170575672         N           Y  41.803597  -73.136274
# 454000     SPOKANEMLS  202317029         N           Y  47.682569 -117.150474
# 126371        Yes-MLS    4464526         N           Y  41.075648  -81.496537
# 177692    Stellar MLS   T3430161         N           Y  27.897541  -82.828367
# 320517        LBARMLS   23007897         N           Y  38.038587  -84.668201
# ...               ...        ...       ...         ...        ...         ...
# 226432          NORES    2319449         N           Y  35.947923  -95.669440
# 297557         SCKMLS     625742         N           Y  37.508339  -97.491268
# 22607           ARMLS    6544289         N           Y  33.429534 -112.513451
# 294983  CRAAR, CDRMLS    2303050         N           Y  42.219625  -91.889053
# 11136           WNBOR      24040         N           Y  41.140529 -102.981270
#
# [500775 rows x 29 columns]

# %%
slice=ret[0:6]
slice
# Out:
#         Unnamed: 0    SALE TYPE            TimeStamp SOLD DATE  \
# 101688      101688  MLS Listing  2023-06-16 13:20:28       NaN
# 454000      454000  MLS Listing  2023-06-16 13:20:28       NaN
# 126371      126371  MLS Listing  2023-06-16 13:20:28       NaN
# 177692      177692  MLS Listing  2023-06-16 13:20:28       NaN
# 320517      320517  MLS Listing  2023-06-16 13:20:28       NaN
# 199663      199663  MLS Listing  2023-06-16 13:20:28       NaN
#
#                     PROPERTY TYPE              ADDRESS            CITY  \
# 101688    Multi-Family (2-4 Unit)     17 Hawthorne Ter      Torrington
# 454000  Single Family Residential  18913 E Buckeye Ave  Spokane Valley
# 126371                  Townhouse       713 Carroll St           Akron
# 177692  Single Family Residential       3964 South Cir           Largo
# 320517  Single Family Residential    131 Gaybourne Way      Versailles
# 199663  Single Family Residential    16850 SW 84th Ave    Palmetto Bay
#
#        STATE OR PROVINCE ZIP OR POSTAL CODE      PRICE  ...  STATUS  \
# 101688                CT               6790   299000.0  ...  Active
# 454000                WA              99027   430000.0  ...  Active
# 126371                OH              44304   180000.0  ...  Active
# 177692                FL              33774   875000.0  ...  Active
# 320517                KY              40383   299900.0  ...  Active
# 199663                FL              33157  1000000.0  ...  Active
#
#         NEXT OPEN HOUSE START TIME NEXT OPEN HOUSE END TIME  \
# 101688                         NaN                      NaN
# 454000                         NaN                      NaN
# 126371                         NaN                      NaN
# 177692                         NaN                      NaN
# 320517                         NaN                      NaN
# 199663       June-17-2023 11:00 AM    June-17-2023 02:00 PM
#
#         URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 101688  https://www.redfin.com/CT/Torrington/17-Hawtho...
# 454000  https://www.redfin.com/WA/Spokane-Valley/18913...
# 126371  https://www.redfin.com/OH/Akron/713-Carroll-St...
# 177692  https://www.redfin.com/FL/Largo/3964-South-Cir...
# 320517  https://www.redfin.com/KY/Versailles/131-Gaybo...
# 199663  https://www.redfin.com/FL/Palmetto-Bay/16850-S...
#
#              SOURCE       MLS#  FAVORITE  INTERESTED   LATITUDE   LONGITUDE
# 101688    Smart MLS  170575672         N           Y  41.803597  -73.136274
# 454000   SPOKANEMLS  202317029         N           Y  47.682569 -117.150474
# 126371      Yes-MLS    4464526         N           Y  41.075648  -81.496537
# 177692  Stellar MLS   T3430161         N           Y  27.897541  -82.828367
# 320517      LBARMLS   23007897         N           Y  38.038587  -84.668201
# 199663       MARMLS  A11369153         N           Y  25.613833  -80.329362
#
# [6 rows x 29 columns]

# %%
jsn=slice.to_json(orient="records")

# %%
import json
parsed=json.loads(jsn)

# %%
parsed
# Out:
# [{'Unnamed: 0': 101688,
#   'SALE TYPE': 'MLS Listing',
#   'TimeStamp': '2023-06-16 13:20:28',
#   'SOLD DATE': None,
#   'PROPERTY TYPE': 'Multi-Family (2-4 Unit)',
#   'ADDRESS': '17 Hawthorne Ter',
#   'CITY': 'Torrington',
#   'STATE OR PROVINCE': 'CT',
#   'ZIP OR POSTAL CODE': 6790,
#   'PRICE': 299000.0,
#   'BEDS': 4.0,
#   'BATHS': 2.0,
#   'LOCATION': 'Torrington',
#   'SQUARE FEET': 1894.0,
#   'LOT SIZE': 5227.0,
#   'YEAR BUILT': 1900.0,
#   'DAYS ON MARKET': 9.0,
#   '$/SQUARE FEET': 158.0,
#   'HOA/MONTH': None,
#   'STATUS': 'Active',
#   'NEXT OPEN HOUSE START TIME': None,
#   'NEXT OPEN HOUSE END TIME': None,
#   'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)': 'https://www.redfin.com/CT/Torrington/17-Hawthorne-Ter-06790/home/107290301',
#   'SOURCE': 'Smart MLS',
#   'MLS#': '170575672',
#   'FAVORITE': 'N',
#   'INTERESTED': 'Y',
#   'LATITUDE': 41.8035967,
#   'LONGITUDE': -73.1362744},
#  {'Unnamed: 0': 454000,
#   'SALE TYPE': 'MLS Listing',
#   'TimeStamp': '2023-06-16 13:20:28',
#   'SOLD DATE': None,
#   'PROPERTY TYPE': 'Single Family Residential',
#   'ADDRESS': '18913 E Buckeye Ave',
#   'CITY': 'Spokane Valley',
#   'STATE OR PROVINCE': 'WA',
#   'ZIP OR POSTAL CODE': '99027',
#   'PRICE': 430000.0,
#   'BEDS': 3.0,
#   'BATHS': 2.0,
#   'LOCATION': 'Spokane Valley',
#   'SQUARE FEET': 1392.0,
#   'LOT SIZE': 6638.0,
#   'YEAR BUILT': 2015.0,
#   'DAYS ON MARKET': 4.0,
#   '$/SQUARE FEET': 309.0,
#   'HOA/MONTH': None,
#   'STATUS': 'Active',
#   'NEXT OPEN HOUSE START TIME': None,
#   'NEXT OPEN HOUSE END TIME': None,
#   'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)': 'https://www.redfin.com/WA/Spokane-Valley/18913-E-Buckeye-Ave-99027/home/119236803',
#   'SOURCE': 'SPOKANEMLS',
#   'MLS#': '202317029',
#   'FAVORITE': 'N',
#   'INTERESTED': 'Y',
#   'LATITUDE': 47.6825694,
#   'LONGITUDE': -117.1504744},
#  {'Unnamed: 0': 126371,
#   'SALE TYPE': 'MLS Listing',
#   'TimeStamp': '2023-06-16 13:20:28',
#   'SOLD DATE': None,
#   'PROPERTY TYPE': 'Townhouse',
#   'ADDRESS': '713 Carroll St',
#   'CITY': 'Akron',
#   'STATE OR PROVINCE': 'OH',
#   'ZIP OR POSTAL CODE': 44304,
#   'PRICE': 180000.0,
#   'BEDS': 5.0,
#   'BATHS': 5.0,
#   'LOCATION': 'Wiley Buchtel Place',
#   'SQUARE FEET': 1496.0,
#   'LOT SIZE': 1210.0,
#   'YEAR BUILT': 1993.0,
#   'DAYS ON MARKET': 10.0,
#   '$/SQUARE FEET': 120.0,
#   'HOA/MONTH': 167.0,
#   'STATUS': 'Active',
#   'NEXT OPEN HOUSE START TIME': None,
#   'NEXT OPEN HOUSE END TIME': None,
#   'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)': 'https://www.redfin.com/OH/Akron/713-Carroll-St-44304/home/66596150',
#   'SOURCE': 'Yes-MLS',
#   'MLS#': '4464526',
#   'FAVORITE': 'N',
#   'INTERESTED': 'Y',
#   'LATITUDE': 41.0756477,
#   'LONGITUDE': -81.4965366},
#  {'Unnamed: 0': 177692,
#   'SALE TYPE': 'MLS Listing',
#   'TimeStamp': '2023-06-16 13:20:28',
#   'SOLD DATE': None,
#   'PROPERTY TYPE': 'Single Family Residential',
#   'ADDRESS': '3964 South Cir',
#   'CITY': 'Largo',
#   'STATE OR PROVINCE': 'FL',
#   'ZIP OR POSTAL CODE': '33774',
#   'PRICE': 875000.0,
#   'BEDS': 3.0,
#   'BATHS': 2.5,
#   'LOCATION': 'HARBOR HILLS 2ND ADD',
#   'SQUARE FEET': 2232.0,
#   'LOT SIZE': 7928.0,
#   'YEAR BUILT': 1958.0,
#   'DAYS ON MARKET': 106.0,
#   '$/SQUARE FEET': 392.0,
#   'HOA/MONTH': None,
#   'STATUS': 'Active',
#   'NEXT OPEN HOUSE START TIME': None,
#   'NEXT OPEN HOUSE END TIME': None,
#   'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)': 'https://www.redfin.com/FL/Largo/3964-South-Cir-33774/home/47919321',
#   'SOURCE': 'Stellar MLS',
#   'MLS#': 'T3430161',
#   'FAVORITE': 'N',
#   'INTERESTED': 'Y',
#   'LATITUDE': 27.8975414,
#   'LONGITUDE': -82.828367},
#  {'Unnamed: 0': 320517,
#   'SALE TYPE': 'MLS Listing',
#   'TimeStamp': '2023-06-16 13:20:28',
#   'SOLD DATE': None,
#   'PROPERTY TYPE': 'Single Family Residential',
#   'ADDRESS': '131 Gaybourne Way',
#   'CITY': 'Versailles',
#   'STATE OR PROVINCE': 'KY',
#   'ZIP OR POSTAL CODE': '40383',
#   'PRICE': 299900.0,
#   'BEDS': 3.0,
#   'BATHS': 1.0,
#   'LOCATION': 'Gaybourne',
#   'SQUARE FEET': 1976.0,
#   'LOT SIZE': 31900.0,
#   'YEAR BUILT': 1965.0,
#   'DAYS ON MARKET': 45.0,
#   '$/SQUARE FEET': 152.0,
#   'HOA/MONTH': None,
#   'STATUS': 'Active',
#   'NEXT OPEN HOUSE START TIME': None,
#   'NEXT OPEN HOUSE END TIME': None,
#   'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)': 'https://www.redfin.com/KY/Versailles/131-Gaybourne-Way-40383/home/83820176',
#   'SOURCE': 'LBARMLS',
#   'MLS#': '23007897',
#   'FAVORITE': 'N',
#   'INTERESTED': 'Y',
#   'LATITUDE': 38.0385874,
#   'LONGITUDE': -84.6682015},
#  {'Unnamed: 0': 199663,
#   'SALE TYPE': 'MLS Listing',
#   'TimeStamp': '2023-06-16 13:20:28',
#   'SOLD DATE': None,
#   'PROPERTY TYPE': 'Single Family Residential',
#   'ADDRESS': '16850 SW 84th Ave',
#   'CITY': 'Palmetto Bay',
#   'STATE OR PROVINCE': 'FL',
#   'ZIP OR POSTAL CODE': '33157',
#   'PRICE': 1000000.0,
#   'BEDS': 3.0,
#   'BATHS': 2.0,
#   'LOCATION': 'OLD CUTLER WEST SEC ONE',
#   'SQUARE FEET': 1965.0,
#   'LOT SIZE': 16560.0,
#   'YEAR BUILT': 1994.0,
#   'DAYS ON MARKET': 69.0,
#   '$/SQUARE FEET': 509.0,
#   'HOA/MONTH': None,
#   'STATUS': 'Active',
#   'NEXT OPEN HOUSE START TIME': 'June-17-2023 11:00 AM',
#   'NEXT OPEN HOUSE END TIME': 'June-17-2023 02:00 PM',
#   'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)': 'https://www.redfin.com/FL/Palmetto-Bay/16850-SW-84th-Ave-33157/home/43171948',
#   'SOURCE': 'MARMLS',
#   'MLS#': 'A11369153',
#   'FAVORITE': 'N',
#   'INTERESTED': 'Y',
#   'LATITUDE': 25.6138325,
#   'LONGITUDE': -80.3293618}]

# %%
li[]    
    for li in parsed:
        h={
            "url":li["URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)"],
            "price":li["PRICE"],
            "bedrooms":li["BEDS"],
            "bathrooms":li["BATHS"],
            "sqft":li["SQUARE FEET"],
            "year_built":li["YEAR BUILT"],
            "address":li["ADDRESS"],
            "state":li["STATE OR PROVINCE"],
            "city":li["CITY"],
            "zip":li["ZIP OR POSTAL CODE"],
            "openHouse_st":li["NEXT OPEN HOUSE START TIME"],
            "openHouse_et":li["NEXT OPEN HOUSE END TIME"],
            "HOA/month":li["HOA/MONTH"],
            "days_on_market":li["DAYS ON MARKET"]            
        }

# %%
def mean(list):
    return sum(list)/len(list)

def is_outlier(points, thresh=3.5):
    """
    Returns a boolean array with True if points are outliers and False 
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), "Volume 16: How to Detect and
        Handle Outliers", The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor. 
    """
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
# COLLABORATIVE RECS -- Future application; need users

### Applying weightings to homes that have been upvoted by users with similar profile characteristics

### Strength of weighting should be inversely related to how close user input is to the user input that liked that house
### Potentially use deviations of scaler to determine how far a value is away from norm

# Python --> Crab library

# %%
# User Input Considerations:

# I'm Feeling Lucky -> Drop a random dot in the housing map

## Price Range: Min - Max

## Property Type

# Minimum Requirements ^^

## State

## City

## Zip Code

## No. of Bedrooms

## No. of Bathrooms

## Square Footage

## Year Built



### NEED TO IDENTIFY WHEN DATA IS SPARSE FOR A CERTAIN AREA AND PRESENT APOLOGY MESSAGE

# %%
aws_bucket=os.getenv('AWS_RE_BUCKET')
aws_key=os.getenv('AWS_RE_BUCKET_KEY')
aws_secret=os.getenv('AWS_RE_BUCKET_SECRET')

date="2023-06-16"
state="CA"
states=['AL',
 'NE',
 'AK',
 'NV',
 'AZ',
 'NH',
 'AR',
 'NJ',
 'CA',
 'NM',
 'CO',
 'NY',
 'CT',
 'NC',
 'DE',
 'ND',
 'DC',
 'OH',
 'FL',
 'OK',
 'GA',
 'OR',
 'HI',
 'PA',
 'ID',
 'PR',
 'IL',
 'RI',
 'IN',
 'SC',
 'IA',
 'SD',
 'KS',
 'TN',
 'KY',
 'TX',
 'LA',
 'UT',
 'ME',
 'VT',
 'MD',
 'VA',
 'MA',
 'VI',
 'MI',
 'WA',
 'MN',
 'WV',
 'MS',
 'WI',
 'MO',
 'WY',
 'MT',
]

# %%
# PULLING IN DATA

df_list=[]
for st in states:
    try:
        df = pd.read_parquet(path=aws_bucket+f"/{date}/{st}.parquet",storage_options={"key":aws_key,"secret":aws_secret})
        df_list.append(df)
    except:
        pass
    
df=pd.concat(df_list)

# %%
df['PROPERTY TYPE'].unique()
# Out:
# array(['Mobile/Manufactured Home', 'Vacant Land',
#        'Single Family Residential', 'Multi-Family (2-4 Unit)',
#        'Multi-Family (5+ Unit)', 'Townhouse', 'Ranch', 'Condo/Co-op',
#        'Other', 'Parking', 'Timeshare', 'Moorage', 'Unknown', 'None'],
#       dtype=object)

# %%
df_copy=deepcopy(df)

# %%
df_copy.columns
# Out:
# Index(['SALE TYPE', 'TimeStamp', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS',
#        'CITY', 'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS',
#        'BATHS', 'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT',
#        'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH', 'STATUS',
#        'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df=df_copy

# %%
import sqlite3

conn=sqlite3.connect( # REPLACE WITH PSYCOPG2 EQUIVALENT
    "C:/Users/rsher/Documents/Projects/PriceYourHome/model-public/model-image/instance/fyh-database.db",
    detect_types=sqlite3.PARSE_DECLTYPES
)
conn.row_factory=sqlite3.Row

df=pd.read_sql_query('SELECT * FROM houses;',conn)

# %%
df
# Out:
#          index    SALE TYPE            TimeStamp SOLD DATE  \
# 0            0  MLS Listing  2023-06-16 13:20:28      None
# 1            1  MLS Listing  2023-06-16 13:20:28      None
# 2            2  MLS Listing  2023-06-16 13:20:28      None
# 3            3  MLS Listing  2023-06-16 13:20:28      None
# 4            4  MLS Listing  2023-06-16 13:20:28      None
# ...        ...          ...                  ...       ...
# 500770  500770  MLS Listing  2023-06-16 13:20:28      None
# 500771  500771  MLS Listing  2023-06-16 13:20:28      None
# 500772  500772  MLS Listing  2023-06-16 13:20:28      None
# 500773  500773  MLS Listing  2023-06-16 13:20:28      None
# 500774  500774  MLS Listing  2023-06-16 13:20:28      None
#
#                     PROPERTY TYPE                     ADDRESS         CITY  \
# 0        Mobile/Manufactured Home         4900 County Road 15  Maplesville
# 1       Single Family Residential            9455 Highway 191  Maplesville
# 2       Single Family Residential          185 County Road 10  Maplesville
# 3       Single Family Residential           231 Birmingham St     Prichard
# 4         Multi-Family (2-4 Unit)       1417 Saint Claire Ave       Mobile
# ...                           ...                         ...          ...
# 500770                Condo/Co-op       28 Miles Ave Unit 103    Whitefish
# 500771                  Townhouse      57 Crestwood Dr Unit A    Whitefish
# 500772                Condo/Co-op  1515 Highway 93 W Unit 326    Whitefish
# 500773                Condo/Co-op  1515 Highway 93 W Unit 327    Whitefish
# 500774                  Townhouse                247 B Elm Ct    Whitefish
#
#        STATE OR PROVINCE ZIP OR POSTAL CODE      PRICE  ...  STATUS  \
# 0                     AL              36750   179000.0  ...  Active
# 1                     AL              36750   650000.0  ...  Active
# 2                     AL              36750   345000.0  ...  Active
# 3                     AL              36610   154000.0  ...  Active
# 4                     AL              36610    38000.0  ...  Active
# ...                  ...                ...        ...  ...     ...
# 500770                MT              59937  2500000.0  ...  Active
# 500771                MT              59937  2906000.0  ...  Active
# 500772                MT              59937  1999000.0  ...  Active
# 500773                MT              59937  1699000.0  ...  Active
# 500774                MT              59937   669900.0  ...  Active
#
#         NEXT OPEN HOUSE START TIME NEXT OPEN HOUSE END TIME  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                      ...
# 500770
# 500771
# 500772
# 500773
# 500774
#
#         URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0       https://www.redfin.com/AL/Maplesville/4900-Cou...
# 1       https://www.redfin.com/AL/Maplesville/9455-AL-...
# 2       https://www.redfin.com/AL/Maplesville/185-Coun...
# 3       https://www.redfin.com/AL/Prichard/231-Birming...
# 4       https://www.redfin.com/AL/Mobile/1417-Saint-Cl...
# ...                                                   ...
# 500770  https://www.redfin.com/MT/Whitefish/28-Miles-A...
# 500771  https://www.redfin.com/MT/Whitefish/57-Crestwo...
# 500772  https://www.redfin.com/MT/Whitefish/1515-U-S-9...
# 500773  https://www.redfin.com/MT/Whitefish/1515-U-S-9...
# 500774  https://www.redfin.com/MT/Whitefish/247-Elm-Ct...
#
#                      SOURCE      MLS#  FAVORITE  INTERESTED   LATITUDE  \
# 0       Greater Alabama MLS   1356836         N           Y  32.752520
# 1       Greater Alabama MLS   1355967         N           Y  32.860645
# 2       Greater Alabama MLS   1293211         N           Y  32.784044
# 3                      BCAR    346365         N           Y  30.738793
# 4                      BCAR    345983         N           Y  30.754935
# ...                     ...       ...       ...         ...        ...
# 500770                MRMLS  22216297         N           Y  48.411804
# 500771                MRMLS  22214972         N           Y  48.427054
# 500772                MRMLS  22200137         N           Y  48.410027
# 500773                MRMLS  22200139         N           Y  48.410027
# 500774                MRMLS  22201866         N           Y  48.385122
#
#          LONGITUDE
# 0       -86.797908
# 1       -86.813504
# 2       -86.876101
# 3       -88.076812
# 4       -88.087958
# ...            ...
# 500770 -114.343121
# 500771 -114.335989
# 500772 -114.366198
# 500773 -114.366198
# 500774 -114.330828
#
# [500775 rows x 29 columns]

# %%
def prepare_model_json(df:pd.DataFrame) ->list[dict]:
    lst=[]
    
    jsn=df.to_json(orient='records')
    parsed=json.loads(jsn)
    
    for li in parsed:
        h={
            "url":li["URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)"],
            "price":li["PRICE"],
            "bedrooms":li["BEDS"],
            "bathrooms":li["BATHS"],
            "sqft":li["SQUARE FEET"],
            "year_built":li["YEAR BUILT"],
            "address":li["ADDRESS"],
            "state":li["STATE OR PROVINCE"],
            "city":li["CITY"],
            "zip":li["ZIP OR POSTAL CODE"],
            "openHouse_st":li["NEXT OPEN HOUSE START TIME"],
            "openHouse_et":li["NEXT OPEN HOUSE END TIME"],
            "HOA/month":li["HOA/MONTH"],
            "days_on_market":li["DAYS ON MARKET"]     
        }
    
        lst.append(h)
        h={}
        
    return lst

# %%
output={
    "data":prepare_model_json(df[0:6])
}

# %%
output
# Out:
# {'data': [{'url': 'https://www.redfin.com/AL/Maplesville/4900-County-Road-15-36750/home/172617556',
#    'price': 179000.0,
#    'bedrooms': 4.0,
#    'bathrooms': 2.0,
#    'sqft': 1976.0,
#    'year_built': 2019.0,
#    'address': '4900 County Road 15',
#    'state': 'AL',
#    'city': 'Maplesville',
#    'zip': '36750',
#    'openHouse_st': None,
#    'openHouse_et': None,
#    'HOA/month': None,
#    'days_on_market': 3.0},
#   {'url': 'https://www.redfin.com/AL/Maplesville/9455-AL-Highway-191-36750/home/117316036',
#    'price': 650000.0,
#    'bedrooms': 5.0,
#    'bathrooms': 3.0,
#    'sqft': 4236.0,
#    'year_built': 2010.0,
#    'address': '9455 Highway 191',
#    'state': 'AL',
#    'city': 'Maplesville',
#    'zip': '36750',
#    'openHouse_st': None,
#    'openHouse_et': None,
#    'HOA/month': None,
#    'days_on_market': 11.0},
#   {'url': 'https://www.redfin.com/AL/Maplesville/185-County-Road-10-36750/home/175843972',
#    'price': 345000.0,
#    'bedrooms': 5.0,
#    'bathrooms': 4.0,
#    'sqft': 2690.0,
#    'year_built': 2002.0,
#    'address': '185 County Road 10',
#    'state': 'AL',
#    'city': 'Maplesville',
#    'zip': '36750',
#    'openHouse_st': None,
#    'openHouse_et': None,
#    'HOA/month': None,
#    'days_on_market': 692.0},
#   {'url': 'https://www.redfin.com/AL/Prichard/231-Birmingham-St-36610/home/129942695',
#    'price': 154000.0,
#    'bedrooms': 3.0,
#    'bathrooms': 2.0,
#    'sqft': 1624.0,
#    'year_built': 1950.0,
#    'address': '231 Birmingham St',
#    'state': 'AL',
#    'city': 'Prichard',
#    'zip': '36610',
#    'openHouse_st': None,
#    'openHouse_et': None,
#    'HOA/month': None,
#    'days_on_market': 7.0},
#   {'url': 'https://www.redfin.com/AL/Mobile/1417-Saint-Clair-Ave-36610/home/130698469',
#    'price': 38000.0,
#    'bedrooms': 4.0,
#    'bathrooms': 2.0,
#    'sqft': 1400.0,
#    'year_built': 1950.0,
#    'address': '1417 Saint Claire Ave',
#    'state': 'AL',
#    'city': 'Mobile',
#    'zip': '36610',
#    'openHouse_st': None,
#    'openHouse_et': None,
#    'HOA/month': None,
#    'days_on_market': 32.0},
#   {'url': 'https://www.redfin.com/AL/Mobile/621-Seminary-St-36610/home/129690512',
#    'price': 38000.0,
#    'bedrooms': 3.0,
#    'bathrooms': 1.0,
#    'sqft': 1032.0,
#    'year_built': 1972.0,
#    'address': '621 Seminary St',
#    'state': 'AL',
#    'city': 'Mobile',
#    'zip': '36610',
#    'openHouse_st': None,
#    'openHouse_et': None,
#    'HOA/month': None,
#    'days_on_market': 80.0}]}

# %%
with open('output.json','w') as f:
    json.dump(output,f,indent=4)

# %%
# PREPROCESSING
prop_types=['Single Family Residential', 'Mobile/Manufactured Home','Townhouse', 'Multi-Family (2-4 Unit)', 'Condo/Co-op','Multi-Family (5+ Unit)']

df=df.applymap(lambda x: np.nan if x=='nan' else x)

#zip_count = df[['ZIP OR POSTAL CODE']].nunique().iloc[0]

#df=df[(df['CITY']=='Houston')&(df['STATE OR PROVINCE']=='TX')] # TEMP LIMITER 1

#df=df[df['PROPERTY TYPE']=='Single Family Residential'] # TEMP LIMITER 2

df=df[df['PROPERTY TYPE'].isin(prop_types)]

df=df.dropna(subset=['ADDRESS','CITY','STATE OR PROVINCE','ZIP OR POSTAL CODE','PROPERTY TYPE','PRICE','BEDS','BATHS','SQUARE FEET','YEAR BUILT','URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)'],axis=0).reset_index(drop=True).apply(lambda row: pd.to_numeric(row,errors='ignore'))


df_full=df

df_final=df_full.drop(['ADDRESS','CITY','STATE OR PROVINCE','ZIP OR POSTAL CODE','PROPERTY TYPE'],axis=1)

# %%
sampled=df.sample(frac=1, replace=False, random_state=42)

# %%
sampled
# Out:
#          index    SALE TYPE            TimeStamp SOLD DATE  \
# 320111  320111  MLS Listing  2023-06-16 13:20:28      None
# 34239    34239  MLS Listing  2023-06-16 13:20:28      None
# 105283  105283  MLS Listing  2023-06-16 13:20:28      None
# 223706  223706  MLS Listing  2023-06-16 13:20:28      None
# 70282    70282  MLS Listing  2023-06-16 13:20:28      None
# ...        ...          ...                  ...       ...
# 259178  259178  MLS Listing  2023-06-16 13:20:28      None
# 365838  365838  MLS Listing  2023-06-16 13:20:28      None
# 131932  131932  MLS Listing  2023-06-16 13:20:28      None
# 146867  146867  MLS Listing  2023-06-16 13:20:28      None
# 121958  121958  MLS Listing  2023-06-16 13:20:28      None
#
#                     PROPERTY TYPE                                ADDRESS  \
# 320111  Single Family Residential                  893 Fiddler Creek Way
# 34239                   Townhouse                      2172 W Million Ln
# 105283  Single Family Residential                       2910 Bromwich Ct
# 223706  Single Family Residential                    96382 E Paradise Rd
# 70282   Single Family Residential                        28 Briarwood Pl
# ...                           ...                                    ...
# 259178  Single Family Residential                  8640 S Blackstone Ave
# 365838  Single Family Residential                            2601 Oak Dr
# 131932  Single Family Residential                            1227 W 25th
# 146867                  Townhouse  205 N Franklin & E Fortune St Unit A2
# 121958                  Townhouse                    1017 Florida Ave NE
#
#                 CITY STATE OR PROVINCE ZIP OR POSTAL CODE      PRICE  ...  \
# 320111     Lexington                KY              40515   599900.0  ...
# 34239   Fayetteville                AR              72704   339900.0  ...
# 105283  Fayetteville                NC              28306   435000.0  ...
# 223706          Gore                OK              74435   475000.0  ...
# 70282        Roswell                NM              88201   330000.0  ...
# ...              ...               ...                ...        ...  ...
# 259178       Chicago                IL              60619   330000.0  ...
# 365838      Amarillo                TX              79107   155000.0  ...
# 131932        Lorain                OH              44052   119900.0  ...
# 146867         Tampa                FL              33602  1850000.0  ...
# 121958    Washington                DC              20002   895000.0  ...
#
#         STATUS  NEXT OPEN HOUSE START TIME NEXT OPEN HOUSE END TIME  \
# 320111  Active
# 34239   Active
# 105283  Active
# 223706  Active
# 70282   Active
# ...        ...                         ...                      ...
# 259178  Active
# 365838  Active
# 131932  Active
# 146867  Active
# 121958  Active
#
#         URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 320111  https://www.redfin.com/KY/Lexington/893-Fiddle...
# 34239   https://www.redfin.com/AR/Fayetteville/2172-W-...
# 105283  https://www.redfin.com/NC/Fayetteville/2910-Br...
# 223706  https://www.redfin.com/OK/Gore/96382-Paradise-...
# 70282   https://www.redfin.com/NM/Roswell/28-Briarwood...
# ...                                                   ...
# 259178  https://www.redfin.com/IL/Chicago/8640-S-Black...
# 365838  https://www.redfin.com/TX/Amarillo/2601-Oak-Dr...
# 131932  https://www.redfin.com/OH/Lorain/1227-W-25th-P...
# 146867  https://www.redfin.com/FL/Tampa/205-N-Franklin...
# 121958  https://www.redfin.com/DC/Washington/1017-Flor...
#
#              SOURCE         MLS#  FAVORITE  INTERESTED   LATITUDE   LONGITUDE
# 320111      LBARMLS     23010381         N           Y  37.960447  -84.503518
# 34239       NWARMLS      1242679         N           Y  36.098520  -94.189602
# 105283       LPRMLS       705644         N           Y  34.994953  -79.012698
# 223706        MLSOK      1058360         N           Y  35.625321  -95.068388
# 70282         NMMLS     20232184         N           Y  33.421485 -104.484347
# ...             ...          ...       ...         ...        ...         ...
# 259178         MRED     11735621         N           Y  41.737483  -87.588132
# 365838       AARMLS        23-59         N           Y  35.239798 -101.828534
# 131932      Yes-MLS      4454790         N           Y  41.447207  -82.186509
# 146867  Stellar MLS     T3414052         N           Y  27.946667  -82.457210
# 121958   BRIGHT MLS  DCDC2026852         N           Y  38.903350  -76.992091
#
# [500775 rows x 29 columns]

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498578 entries, 0 to 498577
# Data columns (total 29 columns):
#  #   Column                                                                                       Non-Null Count   Dtype
# ---  ------                                                                                       --------------   -----
#  0   Unnamed: 0                                                                                   498578 non-null  int64
#  1   SALE TYPE                                                                                    498578 non-null  object
#  2   TimeStamp                                                                                    498578 non-null  object
#  3   SOLD DATE                                                                                    2 non-null       object
#  4   PROPERTY TYPE                                                                                498578 non-null  object
#  5   ADDRESS                                                                                      498578 non-null  object
#  6   CITY                                                                                         498578 non-null  object
#  7   STATE OR PROVINCE                                                                            498578 non-null  object
#  8   ZIP OR POSTAL CODE                                                                           498578 non-null  object
#  9   PRICE                                                                                        498578 non-null  float64
#  10  BEDS                                                                                         498578 non-null  float64
#  11  BATHS                                                                                        498578 non-null  float64
#  12  LOCATION                                                                                     482624 non-null  object
#  13  SQUARE FEET                                                                                  498578 non-null  float64
#  14  LOT SIZE                                                                                     414003 non-null  float64
#  15  YEAR BUILT                                                                                   498578 non-null  float64
#  16  DAYS ON MARKET                                                                               488792 non-null  float64
#  17  $/SQUARE FEET                                                                                498578 non-null  float64
#  18  HOA/MONTH                                                                                    210055 non-null  float64
#  19  STATUS                                                                                       498578 non-null  object
#  20  NEXT OPEN HOUSE START TIME                                                                   45905 non-null   object
#  21  NEXT OPEN HOUSE END TIME                                                                     45905 non-null   object
#  22  URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  498578 non-null  object
#  23  SOURCE                                                                                       498578 non-null  object
#  24  MLS#                                                                                         498578 non-null  object
#  25  FAVORITE                                                                                     498578 non-null  object
#  26  INTERESTED                                                                                   498578 non-null  object
#  27  LATITUDE                                                                                     498578 non-null  float64
#  28  LONGITUDE                                                                                    498578 non-null  float64
# dtypes: float64(11), int64(1), object(17)
# memory usage: 110.3+ MB

# %%
df_NN=sampled[['BEDS','BATHS','SQUARE FEET','YEAR BUILT']]

# %%
# Define the transformations for each column
preprocessor = ColumnTransformer(
transformers=[
    ('minmax_scaler',MinMaxScaler(),['BEDS','BATHS','SQUARE FEET'])
])

# Apply the transformations in a pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

df_NN=pipeline.fit_transform(df_NN)

# %% [markdown]
# ### Need to reduce impact of Year Built, so will probably require custom distance func

# %%
input_df = pd.DataFrame({'BEDS':[4],'BATHS':[4],'SQUARE FEET':[3500]})
input_df

input_t=pipeline.transform(input_df)
input_t
# Out:
# array([[0.04040404, 0.0007    , 0.0001682 ]])

# %%
input_t[0][0]
# Out:
# 0.04040404040404041

# %%
model_weights=np.array([1,1,1])

# %%
from scipy.spatial.distance import euclidean
from sklearn.neighbors import DistanceMetric

def weighted_euclidean(x,y,weights=model_weights):
    
    return euclidean(x,y,weights)


# NEED TO FIGURE OUT HOW TO APPLY WEIGHTS PROPERLY

# %%
knn=NearestNeighbors(n_neighbors=df_NN.shape[0],metric=weighted_euclidean)
knn.fit(df_NN)

distances, indices = knn.kneighbors(input_t)

# %%
indices[0][0]
# Out:
# 434572

# %%
def get_top(df,indices) -> pd.DataFrame:
    top=6
    
    if indices[0].shape[0]<6:
        top=indices[0].shape[0]
        
    return df.iloc[indices[0][0:top]]

results=get_top(sampled,indices)

# %%
results[['BEDS','BATHS','SQUARE FEET']]
# Out:
#         BEDS  BATHS  SQUARE FEET
# 255936   4.0    4.0       3500.0
# 80469    4.0    4.0       3500.0
# 420557   4.0    4.0       3500.0
# 243582   4.0    4.0       3500.0
# 484342   4.0    4.0       3500.0
# 252340   4.0    4.0       3500.0

# %%
def get_top(df,indices) -> pd.DataFrame:
    df_list=[]
    
    c=0
    for index in indices[0]:
        if c>6:
            break
        
        df_list.append(df.loc[index])
        
        c+=1
        
    return pd.concat(df_list,axis=0)

# %%
results=get_top(df_full,indices)

# %%
indices[0].shape
# Out:
# (500775,)

# %%
pd.DataFrame(results)
# Out:
#                                           0
# SALE TYPE                       MLS Listing
# TimeStamp               2023-06-16 13:20:28
# SOLD DATE                               NaN
# PROPERTY TYPE                   Condo/Co-op
# ADDRESS        20281 E Country Club Dr #315
# ...                                     ...
# MLS#                                1229153
# FAVORITE                                  N
# INTERESTED                                Y
# LATITUDE                          35.486368
# LONGITUDE                        -84.381025
#
# [196 rows x 1 columns]

# %%
df_final.loc[indices[0][0:5]]
# Out:
#           SALE TYPE            TimeStamp SOLD DATE     PRICE  BEDS  BATHS  \
# 141908  MLS Listing  2023-06-16 13:20:28       NaN  714000.0   2.0    2.0
# 367240  MLS Listing  2023-06-16 13:20:28       NaN  499000.0   2.0    2.0
# 436674  MLS Listing  2023-06-16 13:20:28       NaN  599000.0   2.0    2.0
# 264621  MLS Listing  2023-06-16 13:20:28       NaN  279000.0   2.0    2.0
# 65432   MLS Listing  2023-06-16 13:20:28       NaN  250000.0   2.0    2.0
#
#                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  ...  STATUS  \
# 141908    HAMPTONS WEST CONDO       1800.0       NaN      1984.0  ...  Active
# 367240           Pebble Beach       1800.0   11473.0      2002.0  ...  Active
# 436674         North Registry       1800.0   69130.0      2022.0  ...  Active
# 264621  Edelweiss on the Lake       1800.0       NaN      1996.0  ...  Active
# 65432       682 - Chino Hills       1800.0       NaN      1978.0  ...  Active
#
#         NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 141908
# 367240
# 436674
# 264621
# 65432
#
#        URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 141908  https://www.redfin.com/FL/Aventura/20281-E-Cou...
# 367240  https://www.redfin.com/TX/Lakehills/918-Pebble...
# 436674  https://www.redfin.com/MA/North-Adams/825-Moha...
# 264621  https://www.redfin.com/IL/Palos-Park/8-Saint-M...
# 65432   https://www.redfin.com/CA/Chino-Hills/15111-Pi...
#
#         SOURCE        MLS# FAVORITE INTERESTED   LATITUDE   LONGITUDE
# 141908  MARMLS   A11343200        N          Y  25.965506  -80.125855
# 367240   Sabor     1649294        N          Y  29.584477  -98.928766
# 436674   BCMLS      237858        N          Y  42.692028  -73.085696
# 264621    MRED    11799789        N          Y  41.677641  -87.817323
# 65432    CRMLS  TR23021111        N          Y  33.978066 -117.711473
#
# [5 rows x 23 columns]

# %%
input_t
# Out:
# array([[2.02020202e-02, 3.00000000e-04, 8.64817406e-05, 2.28832952e+00]])

# %%
def loss_function(index,input,output):
    lst=[]
    
    for i in range(0,3):
        loss=np.abs((input[0][i]-output[index][i]))
        
        lst.append(loss)
        
    return np.mean(lst)

# %%
for index in indices[0][0:5]:
    vals=[]
    val=loss_function(index,input_t,df_NN)
    vals.append(val)
    
val_avg=np.mean(vals)

# %%
val_avg
# Out:
# 0.003368381434391086

# %%
val_avg
# Out:
# 0.0

# %%
df_full.loc[indices[0][0]]
# Out:
# ADDRESS                      1103 Fitzgerald Ct
# CITY                                Summerville
# STATE OR PROVINCE                            SC
# ZIP OR POSTAL CODE                        29485
# PROPERTY TYPE         Single Family Residential
# PRICE                                  503805.0
# BEDS                                        5.0
# BATHS                                       3.0
# SQUARE FEET                              2226.0
# YEAR BUILT                               2748.0
# DAYS ON MARKET                             20.0
# LATITUDE                                32.9431
# LONGITUDE                              -80.2772
# Name: 281733, dtype: object

# %%
all=df_full[(df_full['PROPERTY TYPE']=='Single Family Residential')]

state=df_full[(df_full['PROPERTY TYPE']=='Single Family Residential')&
               (df_full['STATE OR PROVINCE']=='TX')]

city=df_full[(df_full['PROPERTY TYPE']=='Single Family Residential')&
               (df_full['STATE OR PROVINCE']=='TX')&
               (df_full['CITY']=='Houston')]

zip=df_full[(df_full['PROPERTY TYPE']=='Single Family Residential')&
               (df_full['STATE OR PROVINCE']=='TX')&
               (df_full['CITY']=='Houston')&
               (df_full['ZIP OR POSTAL CODE']=='77004')]

slices=[all,state,city,zip]

# %%
def loss_function(index,input,output):
    lst=[]
    
    for i in range(0,3):
        loss=np.abs((input[0][i]-output[index][i]))
        
        lst.append(loss)
        
    return np.mean(lst)

# %%
# OPTIMUM WEIGHT FOR YEAR BUILT SEARCH

# Beware, could take a VERY long time

results={} # Dict of dicts of lists of tuples

for i,slice in enumerate(slices):

    str=""
            
    if i==0:
        str='all'
        
    elif i==1:
        str='state'
        
    elif i==2:
        str='city'
        
    else:
        str='zip'

    results[str]={}
    
    preprocessor = ColumnTransformer(
    transformers=[
        ('minmax_scaler',MinMaxScaler(),['BEDS','BATHS','SQUARE FEET'])
    ])

    pipeline = Pipeline(steps=[('preprocessor', preprocessor)])
    
    slice_np=pipeline.fit_transform(slice[['BEDS','BATHS','SQUARE FEET']])
    
    for year in [2000,2020,1900]:
        
        input_df = pd.DataFrame({'BEDS':[3],'BATHS':[3],'SQUARE FEET':[2600]})
        input_df

        input_t=pipeline.transform(input_df)
        input_t
        
        dct={"weights":[],"loss":[]}

        for w in np.linspace(0,1,21):
            
            def weighted_euclidean(x:np.array,y:np.array):
                weights=np.array([1,1,1,w])
                
                return euclidean(x,y,weights)
            
            knn=NearestNeighbors(n_neighbors=slice_np.shape[0],metric=weighted_euclidean)
            knn.fit(slice_np)

            distances, indices = knn.kneighbors(input_t)
            
            for index in indices[0][0:5]:
                vals=[]
                val=loss_function(index,input_t,slice_np)
                vals.append(val)
                
            val_avg=np.mean(vals)
                
            dct['weights'].append(w)
            dct['loss'].append(val_avg)
                
                
        results[str][year]=dct

# %%
results_df=pd.DataFrame(results['city'][1900])

# %%
results_df
# Out:
#     weights      loss
# 0      0.00  0.000652
# 1      0.05  0.018803
# 2      0.10  0.021078
# 3      0.15  0.021078
# 4      0.20  0.021078
# 5      0.25  0.020951
# 6      0.30  0.034936
# 7      0.35  0.038553
# 8      0.40  0.023034
# 9      0.45  0.023034
# 10     0.50  0.023034
# 11     0.55  0.043775
# 12     0.60  0.043775
# 13     0.65  0.043775
# 14     0.70  0.043775
# 15     0.75  0.043775
# 16     0.80  0.043775
# 17     0.85  0.043775
# 18     0.90  0.043775
# 19     0.95  0.043775
# 20     1.00  0.043775

# %%
# Out:
#                         ADDRESS     CITY STATE OR PROVINCE ZIP OR POSTAL CODE  \
# 349423          3866 Wichita St  Houston                TX              77004
# 349424  2010 Blodgett St Unit H  Houston                TX              77004
# 349426        4909 La Branch St  Houston                TX              77004
# 349429            2705 Anita St  Houston                TX              77004
# 349430           1400 Dennis St  Houston                TX              77004
# ...                         ...      ...               ...                ...
# 349594         3505 Hutchins St  Houston                TX              77004
# 349595    2516 Saint Emanuel St  Houston                TX              77004
# 349596     3409 N Macgregor Way  Houston                TX              77004
# 349597             2201 Ruth St  Houston                TX              77004
# 349598             3706 Drew St  Houston                TX              77004
#
#                     PROPERTY TYPE     PRICE  BEDS  BATHS  SQUARE FEET  \
# 349423  Single Family Residential  320000.0   3.0    2.0       2364.0
# 349424  Single Family Residential  379000.0   2.0    2.0       1799.0
# 349426  Single Family Residential  489000.0   3.0    3.5       2415.0
# 349429  Single Family Residential  699900.0   4.0    3.5       2626.0
# 349430  Single Family Residential  425000.0   4.0    2.0       1592.0
# ...                           ...       ...   ...    ...          ...
# 349594  Single Family Residential  449000.0   3.0    3.5       2547.0
# 349595  Single Family Residential  675000.0   3.0    2.5       2511.0
# 349596  Single Family Residential  775000.0   3.0    5.0       4784.0
# 349597  Single Family Residential  777999.0   5.0    4.5       3500.0
# 349598  Single Family Residential  450000.0   3.0    1.0       1040.0
#
#         YEAR BUILT  DAYS ON MARKET   LATITUDE  LONGITUDE
# 349423      1970.0            20.0  29.712865 -95.351781
# 349424      2007.0             1.0  29.726870 -95.375840
# 349426      2005.0             1.0  29.727276 -95.381520
# 349429      2023.0             3.0  29.734106 -95.361277
# 349430      2000.0             3.0  29.742313 -95.370961
# ...            ...             ...        ...        ...
# 349594      2015.0           279.0  29.733206 -95.368318
# 349595      2022.0           303.0  29.740371 -95.364486
# 349596      1950.0           550.0  29.711009 -95.365352
# 349597      1930.0           662.0  29.726790 -95.373365
# 349598      1953.0           132.0  29.730353 -95.346747
#
# [118 rows x 13 columns]

# %% [markdown]
# ### Warning: Regarding the Nearest Neighbors algorithms,if two neighbors and have identical distances but different labels, the result will depend on the ordering of the training data.

# %%
df_slice=df_full[df_full['ZIP OR POSTAL CODE']=='78705']

# %%
df_slice
# Out:
# Empty DataFrame
# Columns: [ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PROPERTY TYPE, PRICE, BEDS, BATHS, SQUARE FEET, YEAR BUILT, DAYS ON MARKET, LATITUDE, LONGITUDE]
# Index: []

# %%
picks=[]

for i in indices[0]:
    try:
        pick=df_slice.loc[i]
        picks.append(pick)
    except:
        pass
    
    if len(picks)==3:
        break

# %%
picks[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 picks[0]
#
# IndexError: list index out of range

# %%
picks[1]
# Out:
# ADDRESS                   2501 Truxillo St #6
# CITY                                  Houston
# STATE OR PROVINCE                          TX
# ZIP OR POSTAL CODE                      77004
# PROPERTY TYPE         Multi-Family (2-4 Unit)
# PRICE                                780000.0
# BEDS                                      9.0
# BATHS                                     1.0
# SQUARE FEET                            5000.0
# YEAR BUILT                             1930.0
# DAYS ON MARKET                           62.0
# LATITUDE                             29.72961
# LONGITUDE                          -95.367364
# Name: 349536, dtype: object

# %%
df_full.iloc[349519]
# Out:
# ADDRESS                          3342 Reeves St
# CITY                                    Houston
# STATE OR PROVINCE                            TX
# ZIP OR POSTAL CODE                        77004
# PROPERTY TYPE         Single Family Residential
# PRICE                                  250000.0
# BEDS                                        3.0
# BATHS                                       2.0
# SQUARE FEET                              1104.0
# YEAR BUILT                               2002.0
# DAYS ON MARKET                             49.0
# LATITUDE                              29.727252
# LONGITUDE                            -95.355255
# Name: 349519, dtype: object

# %%
input_t
# Out:
# array([[3.03030303e-02, 3.00000000e-04, 8.64817406e-05, 5.72082380e-01]])
